# %%
import os
import json
import numpy as np
import cv2
from pathlib import Path

NB_DIR = Path().resolve()
ROOT = NB_DIR.parent # project root

print("Notebook directory:", NB_DIR)
print("ROOT:", ROOT)

INPUT_DIR = f"{ROOT}/data/lane_data/lane_annotations"
OUTPUT_DIR = f"{ROOT}/data/lane_data/lane_masks"

os.makedirs(OUTPUT_DIR, exist_ok=True)
# Out:
# Notebook directory: /Users/jleto/LocalProjects/rev_vision/notebooks
# ROOT: /Users/jleto/LocalProjects/rev_vision

# %%
import os
import json
import numpy as np
from PIL import Image
from labelme import utils

for file in os.listdir(INPUT_DIR):
    if not file.endswith(".json"):
        continue

    json_path = os.path.join(INPUT_DIR, file)
    with open(json_path, "r") as f:
        data = json.load(f)

    image_data = utils.image.img_b64_to_arr(data["imageData"])
    label_name_to_value = {"_background_": 0}

    for shape in data["shapes"]:
        label_name_to_value[shape["label"]] = 1

    # FIX HERE — unpack the tuple
    label, _ = utils.shapes_to_label(
        image_data.shape,
        data["shapes"],
        label_name_to_value
    )

    label = (label.astype(np.uint8)) * 255

    out_path = os.path.join(OUTPUT_DIR, file.replace(".json", ".png"))
    Image.fromarray(label).save(out_path)
    print(f"Saved: {out_path}")
# Out:
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0007.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0011.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0031.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0027.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0026.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0030.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0010.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0006.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0021.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0001.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0017.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0016.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0020.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0023.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0019.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0015.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0003.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0002.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0014.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0018.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0022.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0029.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0013.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0005.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0025.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0009.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0008.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0032.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0024.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0004.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0012.png
# Saved: /Users/jleto/LocalProjects/rev_vision/data/lane_data/lane_masks/frame_0028.png
